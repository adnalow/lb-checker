# %%
class admin:
    def priv():
        print("lowna")

    def priv2():
        print("yowyow")

class regs(admin):
    def priv2():
        pass

def login():
    admin_user = {"yow": "pass"}
    regular_users = {
        "kin": "bon",
        "user2": "password2",
        "user3": "password3",
        "user4": "password4",
        "user5": "password5",
        "user6": "password6",
        "user7": "password7",
        "user8": "password8"
    }

    username = input("Enter your username: ")
    password = input("Enter your password: ")

    if username in admin_user and password == admin_user[username]:
        
    elif username in regular_users and password == regular_users[username]:
        regs
    else:
        print("Invalid username or password. Please try again.")

# %%
def liab_add():
    global liab_all = {}
    liab_1_name = input("Insert Liabilities: ")
    liab_1_price = input("Insert Price")

    liab_all[liab_1_name] = liab_1_price
    return result

def liab_view():
    print(liab_all)

# %%
def liabilities_checker(username, password, action, amount):

    username = input("Username")
    password = input("password")
    action = input("action")
    amount = input("amount")
    
    # Check if user is admin
    if username == "admin" and password == "adminpassword":
        if action == "add":
            # Add liability
            liabilities.append(amount)
            return "Liability added successfully."
        elif action == "remove":
            if amount in liabilities:
                # Remove liability
                liabilities.remove(amount)
                return "Liability removed successfully."
            else:
                return "Liability not found."
        else:
            return "Invalid action. Please use 'add' or 'remove'."
    else:
        return "Access denied. You must be an admin to perform this action."

# %%
liabilities_checker()

# %%
# Initialize a dictionary to store user account information
users = {}

# Define a function to create new user accounts
def create_user():
    username = input("Enter a username: ")
    password = input("Enter a password: ")
    account_type = input("Enter an account type (admin/regular): ")
    users[username] = {"password": password, "account_type": account_type}
    print("User account created successfully.")

# Define a function to log in to an existing user account
def login():
    username = input("Enter your username: ")
    password = input("Enter your password: ")
    if username in users and users[username]["password"] == password:
        print("Login successful.")
        return users[username]["account_type"]
    else:
        print("Invalid username or password.")
        return None

# Define a function to manage liabilities
def manage_liabilities():
    if account_type == "admin":
        while True:
            print("Select an option:")
            print("1. Add liability")
            print("2. Remove liability")
            print("3. View liabilities")
            print("4. Exit")
            option = input("Enter option number: ")
            if option == "1":
                name = input("Enter liability name: ")
                price = float(input("Enter liability price: "))
                liabilities[name] = price
                print("Liability added successfully.")
            elif option == "2":
                name = input("Enter liability name: ")
                if name in liabilities:
                    del liabilities[name]
                    print("Liability removed successfully.")
                else:
                    print("Liability not found.")
            elif option == "3":
                print("Liabilities:")
                for name, price in liabilities.items():
                    print(f"{name}: ${price:.2f}")
            elif option == "4":
                break
            else:
                print("Invalid option.")
    else:
        print("You do not have permission to manage liabilities.")

# Initialize an empty dictionary to store liabilities
liabilities = {}

# Main program loop
while True:
    print("Select an option:")
    print("1. Create user account")
    print("2. Log in")
    print("3. Manage liabilities")
    print("4. Exit")
    option = input("Enter option number: ")
    if option == "1":
        create_user()
    elif option == "2":
        account_type = login()
        if account_type is None:
            continue
    elif option == "3":
        manage_liabilities()
    elif option == "4":
        break
    else:
        print("Invalid option.")

# %%
users = {}

def create_user():
    username, password, account_type = input("Enter username, password, account type: ").split()
    users[username] = {"password": password, "account_type": account_type, "liabilities": {}}
    print("User account created.")

def login():
    username, password = input("Enter username, password: ").split()
    if username in users and users[username]["password"] == password:
        print("Login successful.")
        return username, users[username]["account_type"]
    print("Invalid username or password.")
    return None, None

def manage_liabilities(account_type):
    if account_type != "admin":
        print("You do not have permission to manage liabilities.")
        return
    while True:
        print("Select an option:")
        print("1. Add liability")
        print("2. Remove liability")
        print("3. View liabilities")
        print("4. Exit")
        option = input("Enter option number: ")
        if option == "1":
            name, price = input("Enter liability name, price: ").split()
            users[username]["liabilities"][name] = float(price)
            print("Liability added.")
        elif option == "2":
            name = input("Enter liability name: ")
            if name in users[username]["liabilities"]:
                del users[username]["liabilities"][name]
                print("Liability removed.")
            else:
                print("Liability not found.")
        elif option == "3":
            print("Liabilities:")
            for name, price in users[username]["liabilities"].items():
                print(f"{name}: ${price:.2f}")
        elif option == "4":
            break
        else:
            print("Invalid option.")

while True:
    print("Select an option:")
    print("1. Create user account")
    print("2. Log in")
    print("3. Manage liabilities")
    print("4. Exit")
    option = input("Enter option number: ")
    if option == "1":
        create_user()
    elif option == "2":
        username, account_type = login()
    elif option == "3":
        manage_liabilities(account_type)
    elif option == "4":
        break
    else:
        print("Invalid option.")

# %%
admin_user = {
    "adrian": "luna"
}

regular_user = {
        "Gab": "gab",
        "kim": "kim",
        "user3": "password3",
        "user4": "password4",
        "user5": "password5",
        "user6": "password6",
        "user7": "password7",
        "user8": "password8"
}

def login_admin():
    while True:
        username = input("What's your username?")
        password = input("What's your password?")
        if username in admin_user and admin_user[username] == password:
            print("Welcome Admin!")
            break
        else:
            print("Invalid username or password")
    

liab_list_name = []
liab_list_price = []

def liab_admin():
    
    print("Select an option:")
    print("1. Add liability")
    print("2. Remove liability")
    print("3. Exit")
    option = input("What do you want to do? ")

    if option == '1':
        liab_name = input("What's the name of the liability?")
        liab_list_name.append(liab_name)
        liab_price = input("Price")
        price = float(liab_price)
        liab_list_price.append(price)
    elif option == '2':
        print("All liabilities: ")
        print(liab_list_name[0], liab_list_price[0])
        print(liab_list_name[1], liab_list_price[1])
        print(liab_list_name[2], liab_list_price[2])
        print(liab_list_name[3], liab_list_price[3])
        print(liab_list_name[4], liab_list_price[4])


while True:
    print("Select an option:")
    print("1. Log in(admin)")
    print("2. Log in(regular)")
    print("3. Manage liabilities")
    print("4. Exit")
    option = input("Enter option number: ")
    if option == "1":
        login_admin()
    if option == "2":
        login_regular()
    elif option == "3":
        manage_liabilities(account_type)
    elif option == "4":
        break
    else:
        print("Invalid option.")

# %%
admin_user = {
    "adrian": "luna"
}

regular_user = {
        "Gab": "perez",
        "kim": "bautista",
        "elwin": "baredo",
        "gelo": "baricante",
        "gian": "gersaniba",
        "russel": "garcia",
        "james": "diola",
        "boris": "hernandez"
}

liab_list_name = []
liab_list_price = []


def liab_admin():
    
    print("Select an option:")
    print("1. Add liability")
    print("2. Remove liability")
    print("3. Exit")
    option = input("What do you want to do? ")

    if option == '1':
        liab_name = input("What's the name of the liability?")
        liab_list_name.append(liab_name)
        liab_price = input("Price")
        price = int(liab_price)
        liab_list_price.append(price)
        

    elif option == '2':
        if len(liab_list_name) == 0:
            print("There are no liabilities to remove.")
        else:
             print("What do you want to remove?")
                
        for i in range(len(liab_list_name)):
            print(f"[{i+1}]", liab_list_name[i], liab_list_price[i] if i < len(liab_list_price) else '')
        
        option_1 = input("Type your answer: ")

        if option_1 == '1':
            del liab_list_name[0]
            del liab_list_price[0]
        elif option_1 == '2':
            del liab_list_name[1]
            del liab_list_price[1]
        elif option_1 == '3':
            del liab_list_name[2]
            del liab_list_price[2]
        elif option_1 == '4':
            del liab_list_name[3]
            del liab_list_price[3]
        elif option_1 == '5':
            del liab_list_name[4]
            del liab_list_price[4]
        else :
            break




            

      
            #to see all the liabilities
        #for i in range(len(liab_list_name)):
            #print(liab_list_name[i], liab_list_price[i] if i < len(liab_list_price) else '')

# %%
liab_admin()

# %%
admin_user = {
    "adrian": "luna"
}

regular_user = {
    "Gab": "perez",
    "kim": "bautista",
    "elwin": "baredo",
    "gelo": "baricante",
    "gian": "gersaniba",
    "russel": "garcia",
    "james": "diola",
    "boris": "hernandez"
}

liab_list_name = []
liab_list_price = []

def liab_admin():
    while True:
        print("Select an option:")
        print("1. Add liability")
        print("2. Remove liability")
        print("3. Exit")
        option = input("What do you want to do? ")

        if option == '1':
            liab_name = input("What's the name of the liability? ")
            liab_list_name.append(liab_name)
            liab_price = input("Price: ")
            price = int(liab_price)
            liab_list_price.append(price)
            print(f"{liab_name} has been added with price {price}.")
            
        
        elif option == '2':
            if len(liab_list_name) == 0:
                print("There are no liabilities to remove.")
            else:
                print("Which liability do you want to remove?")
                
            for i in range(len(liab_list_name)):
                print(f"[{i+1}] {liab_list_name[i]} {liab_list_price[i] if i < len(liab_list_price) else ''}")
            
            option_1 = input("Type the number of the liability you want to remove, or type 0 to cancel: ")

            if option_1 == '0':
                continue
            elif option_1.isdigit() and 1 <= int(option_1) <= len(liab_list_name):
                index = int(option_1) - 1
                del liab_list_name[index]
                del liab_list_price[index]
                print(f"The liability {liab_list_name[index]} has been removed.")
            else:
                print("Invalid input.")
        
        elif option == '3':
            print("Exiting liability admin...")
            break
        
        else:
            print("Invalid input.")
            
    print("Goodbye!")

liab_admin()

# %%
def liab_admin():
    while True:
        print("Select an option:")
        print("1. Add liability")
        print("2. Remove liability")
        print("3. Exit")
        option = input("What do you want to do? ")

        if option == '1':
            liab_name = input("What's the name of the liability? ")
            liab_list_name.append(liab_name)
            liab_price = input("Price: ")
            price = int(liab_price)
            liab_list_price.append(price)
            print(f"{liab_name} has been added with price {price}.")

        elif option == '2':
            print("Which liability do you want to remove?")
            for i in range(len(liab_list_name)):
                print(f"[{i+1}] {liab_list_name[i]} {liab_list_price[i] if i < len(liab_list_price) else ''}")
            option_1 = input("Type the number of the liability you want to remove, or type 0 to cancel: ")
            if option_1 == '0':
                continue
            elif option_1.isdigit() and 1 <= int(option_1) <= len(liab_list_name):
                index = int(option_1) - 1
                del liab_list_name[index]
                del liab_list_price[index]
                print(f"The liability has been removed.")
            else:
                print("Invalid input.")

        elif option == '3':
            print("Exiting liability admin...")
            break

        else:
            print("Invalid input.")

    print("Liabilities:")
    for i in range(len(liab_list_name)):
        print(f"[{i+1}] {liab_list_name[i]} {liab_list_price[i] if i < len(liab_list_price) else ''}")
    print("Goodbye!")

# %%
liab_admin()
